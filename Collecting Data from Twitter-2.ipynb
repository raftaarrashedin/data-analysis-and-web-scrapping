# %%
pip install selenium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.26.15)

# %%
pip install msedge-selenium-tools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: msedge-selenium-tools in /usr/local/lib/python3.10/dist-packages (3.141.4)
# Requirement already satisfied: selenium==3.141 in /usr/local/lib/python3.10/dist-packages (from msedge-selenium-tools) (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from selenium==3.141->msedge-selenium-tools) (1.26.15)

# %%
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from msedge.selenium_tools import Edge, EdgeOptions

# %%
options = EdgeOptions()

# %%
# from selenium.webdriver import Edge, EdgeOptions
# options = EdgeOptions()
# Add any desired options to the options object

# driver = Edge(options=options)

# The Edge driver should now initialize without any errors

# %%
options.use_chromium = True
driver = Edge(options = options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-de7f2d383dfc> in <cell line: 2>()
#       1 options.use_chromium = True
# ----> 2 driver = Edge(options = options)
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'options'
