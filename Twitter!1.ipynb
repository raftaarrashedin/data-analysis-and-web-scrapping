# %%
pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import snscrape.modules.twitter as snstwitter
import pandas as pd

# %%
query = "محبت"

tweets = []
limits = 100

for tweet in snstwitter.TwitterSearchScraper(query).get_items() :
  if len(tweets) == limits :
    break
  else :
    tweets.append([tweet.date,tweet.username,tweet.content])


df = pd.DataFrame(tweets, columns=['Date','User','Tweet'])
# Out:
# <ipython-input-13-37b05813128f>:10: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date,tweet.username,tweet.content])
# <ipython-input-13-37b05813128f>:10: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date,tweet.username,tweet.content])

# %%
df.head()
# Out:
#                        Date             User  \
# 0 2023-04-11 09:26:23+00:00  Altaf6752995257
# 1 2023-04-11 09:26:15+00:00     heliwasepahi
# 2 2023-04-11 09:26:14+00:00      _lovie_love
# 3 2023-04-11 09:26:05+00:00       r_masoudi1
# 4 2023-04-11 09:25:51+00:00   mfaraz_ulislam
#
#                                                Tweet
# 0  @Saqibali1211 جيڪو عورتن سان محبت ڪندا آھن ھو ...
# 1  من برای هرکی خودمو نگرفتم و نریدم بهش بهم ثابت...
# 2  #عاشق_رسولﷺ\nمحبت انسان کو دلیر بنا دیتی ہے چہ...
# 3  @seyed188 حب علی به دینه معیار و محک، ظلم‌هایی...
# 4  تم اپنے رَبّ سے معافی مانگو، پھر اسی کی طرف رُ...

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler("77e4Vi84vuEuHLxzklffj7dBG","d8kCd2BpPFsvMgAeLH1cwBbR0ohTi2vSi1PKiiBqVROzfCQktS")
auth.set_access_token("1034330380239687680-jXntoCgPdwXTgTBLWN2B1Use0FpSmn","zrJRvQqaTfxWcRGSKTNCnVS4BLqyEKXv4Q39W8ChRjvnc")
