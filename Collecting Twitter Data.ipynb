# %%
pip install selenium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import csv
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver import chrome
from selenium import webdriver
# from msedge.selenium_tools import Edge, EdgeOptions

# %%
# chrome_options = webdriver.ChromeOptions()

# %%
# chrome_options.add_argument('--headless')

# %%
# driver = webdriver.Chrome(executable_path='C:\Users\Sgrams\Downloads\chromedriver_win32',options=chrome_options)
from selenium import webdriver

# Set the path to your Chrome driver executable
chrome_driver_path = r'C:\Users\Sgrams\Downloads\chromedriver_win32\chromedriver.exe'

# Create ChromeOptions and set the binary path
chrome_options = webdriver.ChromeOptions()
chrome_options.binary_location = r'C:\Program Files\Google\Chrome\Application\chrome.exe'

# Create a new Chrome webdriver instance
driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)

# Rest of your code...
# Out:
# <ipython-input-13-1b1495459f22>:12: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-1b1495459f22> in <cell line: 12>()
#      10
#      11 # Create a new Chrome webdriver instance
# ---> 12 driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)
#      13
#      14 # Rest of your code...
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      82         service.path = DriverFinder.get_path(service, options)
#      83
# ---> 84         super().__init__(
# ...

# %%
from selenium import webdriver

# Set the path to your Chrome driver executable
chrome_driver_path = r'C:\Users\Sgrams\Downloads\chromedriver_win32\chromedriver.exe'

# Specify the path to the Chrome binary
chrome_binary_path = r'C:\Program Files\Google\Chrome\Application'  # Replace with the actual path

# Create ChromeOptions and set the binary path
chrome_options = webdriver.ChromeOptions()
chrome_options.binary_location = chrome_binary_path

# Create a new Chrome webdriver instance
driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)

# Rest of your code...


# Now you can use the driver to automate the browser, perform actions, and scrape data
# For example, you can navigate to a website:
driver.get('https://www.example.com')

# Extract data from the website using the appropriate methods provided by the Selenium library

# Remember to close the driver when you're done
driver.quit()
# Out:
# <ipython-input-12-fb655f23edd9>:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-12-fb655f23edd9> in <cell line: 14>()
#      12
#      13 # Create a new Chrome webdriver instance
# ---> 14 driver = webdriver.Chrome(executable_path=chrome_driver_path, options=chrome_options)
#      15
#      16 # Rest of your code...
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      82         service.path = DriverFinder.get_path(service, options)
#      83
# ---> 84         super().__init__(
# ...
