# %%
import tweepy

# Twitter API credentials
consumer_key = "BiMkK3xefyYXYEdiLgTYJCj2l"
consumer_secret = "2iCmDfgL2fMfryjMEwNObPWlAz3bEBE0YNbSWbAhxTJVP0WQQL"
access_key = "1034330380239687680-cFVZlquShqSv2HY7U4UD0aSaQZlUrm"
access_secret = "0wEWSOSWgAImnXYwhkzp4VTw6WNZH0T0lZMDAdxNu8o7r"

# Authenticate with the Twitter API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

# Initialize the API object
api = tweepy.API(auth)

# Search for tweets containing a particular keyword
tweets = tweepy.Cursor(api.search_tweets, q='lang:ur', tweet_mode='extended').items(100)

# Print the text of each tweet
for tweet in tweets:
    print(tweet.full_text)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# <ipython-input-1-ea00ce308710> in <cell line: 20>()
#      18
#      19 # Print the text of each tweet
# ---> 20 for tweet in tweets:
#      21     print(tweet.full_text)
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# /usr/local/lib/python3.9/dist-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# --> 286             self.current_page = next(self.page_iterator)
#     287             while len(self.current_page) == 0:
#     288                 self.current_page = next(self.page_iterator)
#
# ...
