# %%
pip install selenium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 42.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.2 MB/s eta 0:00:00
# ...

# %%
import selenium

# %%
# from selenium import webdriver

# %%
from selenium import webdriver

chrome_options = webdriver.ChromeOptions()
chrome_options.binary_location = r'C:\Program Files\Google\Chrome\Application\chrome.exe'

driver = webdriver.Chrome(executable_path=r'C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe', options=chrome_options)
# Out:
# <ipython-input-15-5ac90fb062b9>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=r'C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe', options=chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-15-5ac90fb062b9> in <cell line: 6>()
#       4 chrome_options.binary_location = r'C:\Program Files\Google\Chrome\Application\chrome.exe'
#       5
# ----> 6 driver = webdriver.Chrome(executable_path=r'C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe', options=chrome_options)
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
# ...

# %%
# chrome_options = webdriver.ChromeOptions()

# chrome_options.binary_location = 'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe'

# driver = webdriver.Chrome(executable_path='C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe', chrome_options = chrome_options)
# Out:
# <ipython-input-11-c1c9b7b3e74c>:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='C:\\Users\\Sgrams\\Downloads\\chromedriver_win32 (2)\\chromedriver.exe', chrome_options = chrome_options)
# <ipython-input-11-c1c9b7b3e74c>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path='C:\\Users\\Sgrams\\Downloads\\chromedriver_win32 (2)\\chromedriver.exe', chrome_options = chrome_options)
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-11-c1c9b7b3e74c> in <cell line: 5>()
#       3 chrome_options.binary_location = 'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe'
#       4
# ...

# %%
driver = webdriver.Chrome(executable_path = r"C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe")
driver.maximize_window()
driver.get("https://chromedriver.storage.googleapis.com/index.html?path=113.0.5672.63/")
# C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
# Out:
# <ipython-input-19-7bce26772fdc>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = r"C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe")
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-19-7bce26772fdc> in <cell line: 1>()
# ----> 1 driver = webdriver.Chrome(executable_path = r"C:\Users\Sgrams\Downloads\chromedriver_win32 (2)\chromedriver.exe")
#       2 driver.maximize_window()
#       3 driver.get("https://chromedriver.storage.googleapis.com/index.html?path=113.0.5672.63/")
#       4 # C:\Program Files (x86)\Google\Chrome\Application\chrome.exe
#
# ...

# %%
# driver = webdriver.Chrome()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-ec48251f04f8> in <cell line: 1>()
# ----> 1 driver = webdriver.Chrome()
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      82         service.path = DriverFinder.get_path(service, options)
#      83
# ---> 84         super().__init__(
#      85             DesiredCapabilities.CHROME["browserName"],
#      86             "goog",
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/chromium/webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#     102
#     103         try:
# --> 104             super().__init__(
# ...
