# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/mercedes- benz.csv', usecols =['X1','X2'])

# %%
df.head()
# Out:
#   X1  X2
# 0  v  at
# 1  t  av
# 2  w   n
# 3  t   n
# 4  v   n

# %%
df.shape
# Out:
# (4209, 2)

# %%
pd.get_dummies(df).shape
# Out:
# (4209, 71)

# %%
len(df['X1'].unique())
# Out:
# 27

# %%
len(df['X2'].unique())
# Out:
# 44

# %%
# let's have a look at how many labels

for col in df.columns[0:] :
  print(col, ': ', len(df[col].unique()), ' labels')
# Out:
# X1 :  27  labels
# X2 :  44  labels

# %%
# let's obtain the counts for each one of the labels in variables X2
# Let's capture this in a dictionary that we can use to re-map the labels

df.X2.value_counts().to_dict()
# Out:
# {'as': 1659,
#  'ae': 496,
#  'ai': 415,
#  'm': 367,
#  'ak': 265,
#  'r': 153,
#  'n': 137,
#  's': 94,
#  'f': 87,
#  'e': 81,
#  'aq': 63,
#  'ay': 54,
#  'a': 47,
#  't': 29,
#  'k': 25,
#  'i': 25,
#  'b': 21,
#  'ao': 20,
#  'ag': 19,
#  'z': 19,
#  'd': 18,
#  'ac': 13,
#  'g': 12,
#  'ap': 11,
#  'y': 11,
#  'x': 10,
#  'aw': 8,
#  'at': 6,
#  'h': 6,
#  'al': 5,
#  'an': 5,
#  'q': 5,
#  'av': 4,
#  'ah': 4,
#  'p': 4,
#  'au': 3,
#  'am': 1,
#  'j': 1,
#  'af': 1,
#  'l': 1,
#  'aa': 1,
#  'c': 1,
#  'o': 1,
#  'ar': 1}

# %%
# and now let's replace each label in X2 by its count

# first we make a dictionary that maps each label to the counts

df_frequency_map = df.X2.value_counts().to_dict()

# %%
df.X2 = df.X2.map(df_frequency_map)

# %%
df.head()
# Out:
#   X1   X2
# 0  v    6
# 1  t    4
# 2  w  137
# 3  t  137
# 4  v  137
