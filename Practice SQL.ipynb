# %%
# !pip install db-sqlite3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.0/172.0 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for db-sqlite3: filename=db_sqlite3-0.0.1-py3-none-any.whl size=1794 sha256=3a3aeba3fd259ad1c7acf6f6801295de9d4ae7b25de82b1f9eb36e233e4a3b67
#   Stored in directory: /root/.cache/pip/wheels/20/fb/1b/2ba46d337e706f0315053f19c8d6e83fc2431c41b7525caaa2
# ...
#   Created wheel for db: filename=db-0.1.1-py3-none-any.whl size=3891 sha256=6bd405fa62a89f07c7dd8f6f6bed98f3673cb094df4e28644f609f75efe84baf
#   Stored in directory: /root/.cache/pip/wheels/85/9b/62/ebd5df18a3e9d5ead2b27c11d493f87aedc9d5e3bb0539010c
# ...
#   Created wheel for antiorm: filename=antiorm-1.2.1-py3-none-any.whl size=31677 sha256=cd59fcf2d8125c993d8791ed59e9ef0cc19d478309f1c01c05c601d12f25ab44
# ...

# %%
import pandas as pd
import sqlite3
from datetime import date

# %%
db = sqlite3.connect("raftaar.db")

# %%
# db.execute("drop table if exists")
try :
  db.execute("create table student(Name text, Date datetime, Mobile text, Mail text)")
except :
  print("Already table existed ")

# %%
db = sqlite3.connect("raftaar.db")

# %%
Name = "raftaar69"
Date = date.today().strftime("%d-%m-%y")
Mobile = "9009"
Mail = "raftaar@xd.com"

# %%
cmd = "insert into student(Name, Date, Mobile, Mail) values('{}','{}','{}','{}')".format(Name, Date, Mobile, Mail)
db.execute(cmd)
db.commit()

# %%
# db = sqlite3.connect("raftaar.db")
slct = db.execute("select * from student")

for row in slct:
  print(row)
# Out:
# ('raftaar69', '12-04-23', '9009', 'raftaar@xd.com')

# %%
db = sqlite3.connect("raftaar.db")
query = """
  select * from student
"""
df = pd.read_sql_query(query,db)

# %%
df.head()
# Out:
#         Name      Date Mobile            Mail
# 0  raftaar69  12-04-23   9009  raftaar@xd.com
