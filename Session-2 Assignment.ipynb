# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Q 1 :- Create a new dataset for exclusively Toyota cars.

# %%
df = pd.read_csv('AutoDataset.csv')

# %%
df.head()
# Out:
#     symboling   normalized-losses         make  fuel-type  aspiration  \
# 0           3                 NaN  alfa-romero        gas         std
# 1           3                 NaN  alfa-romero        gas         std
# 2           1                 NaN  alfa-romero        gas         std
# 3           2               164.0         audi        gas         std
# 4           2               164.0         audi        gas         std
#
#    num-of-doors   body-style  drive-wheels  engine-location   wheel-base  ...  \
# 0           two  convertible           rwd            front         88.6  ...
# 1           two  convertible           rwd            front         88.6  ...
# 2           two    hatchback           rwd            front         94.5  ...
# 3          four        sedan           fwd            front         99.8  ...
# 4          four        sedan           4wd            front         99.4  ...
#
# ...

# %%
df.columns
# Out:
# Index([' symboling', ' normalized-losses', '      make', ' fuel-type',
#        ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels',
#        ' engine-location', ' wheel-base', ' length', ' width', ' height',
#        ' curb-weight', ' engine-type', ' num-of-cylinders', ' engine-size',
#        ' fuel-system', ' bore', ' stroke', ' compression-ratio', ' horsepower',
#        ' peak-rpm', ' city-mpg', ' highway-mpg', ' price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.loc[:,['      make']].head(100)
# Out:
#            make
# 0   alfa-romero
# 1   alfa-romero
# 2   alfa-romero
# 3          audi
# 4          audi
# ..          ...
# 95       nissan
# 96       nissan
# 97       nissan
# 98       nissan
# 99       nissan
#
# [100 rows x 1 columns]

# %%
toyotaData = df[df['      make'] == "toyota"]
toyotaData.head()
# Out:
#       symboling   normalized-losses       make  fuel-type  aspiration  \
# 150           1                87.0     toyota        gas         std
# 151           1                87.0     toyota        gas         std
# 152           1                74.0     toyota        gas         std
# 153           0                77.0     toyota        gas         std
# 154           0                81.0     toyota        gas         std
#
#      num-of-doors  body-style  drive-wheels  engine-location   wheel-base  \
# 150           two   hatchback           fwd            front         95.7
# 151           two   hatchback           fwd            front         95.7
# 152          four   hatchback           fwd            front         95.7
# 153          four       wagon           fwd            front         95.7
# 154          four       wagon           4wd            front         95.7
#
#      ...   engine-size   fuel-system   bore   stroke  compression-ratio  \
# ...

# %% [markdown]
# Q 2 -> Create a new dataset for all cars with city.mpg greater than 30 and engine size is less than 120

# %%
data1 = df[(df[' city-mpg']> 30) &(df[' engine-size']<120)]
data1.head()
# Out:
#      symboling   normalized-losses       make  fuel-type  aspiration  \
# 18           2               121.0  chevrolet        gas         std
# 19           1                98.0  chevrolet        gas         std
# 20           0                81.0  chevrolet        gas         std
# 21           1               118.0      dodge        gas         std
# 22           1               118.0      dodge        gas         std
#
#     num-of-doors  body-style  drive-wheels  engine-location   wheel-base  ...  \
# 18           two   hatchback           fwd            front         88.4  ...
# 19           two   hatchback           fwd            front         94.5  ...
# 20          four       sedan           fwd            front         94.5  ...
# 21           two   hatchback           fwd            front         93.7  ...
# 22           two   hatchback           fwd            front         93.7  ...
#
#      engine-size   fuel-system   bore   stroke  compression-ratio  horsepower  \
# ...

# %% [markdown]
# Q 3 -> Create a new dataset by taking only  sedan cars. Keep only four variables(Make, body style, fuel type, price) in the final dataset

# %%
data2 = df[df[' body-style'] == "sedan"]
data3 = data2[['      make',' body-style',' fuel-type',' price']]
data2.head()
# Out:
#     symboling   normalized-losses       make  fuel-type  aspiration  \
# 3           2               164.0       audi        gas         std
# 4           2               164.0       audi        gas         std
# 5           2                 NaN       audi        gas         std
# 6           1               158.0       audi        gas         std
# 8           1               158.0       audi        gas       turbo
#
#    num-of-doors  body-style  drive-wheels  engine-location   wheel-base  ...  \
# 3          four       sedan           fwd            front         99.8  ...
# 4          four       sedan           4wd            front         99.4  ...
# 5           two       sedan           fwd            front         99.8  ...
# 6          four       sedan           fwd            front        105.8  ...
# 8          four       sedan           fwd            front        105.8  ...
#
#     engine-size   fuel-system   bore   stroke  compression-ratio  horsepower  \
# ...

# %% [markdown]
# Q 4 :- Create a new dataset by taking Audi, BMW or Porsche company makes. Drop two variables from the resultant dataset(price and normalized losses)

# %%
data4 = df.drop([' price',' normalized-losses'], axis =1)
data5 = data4[(data4['      make'] == "audi") | (data4['      make'] == "bmw") | (data4['      make'] == "porsche")]
data5.head()
# Out:
#     symboling       make  fuel-type  aspiration  num-of-doors  body-style  \
# 3           2       audi        gas         std          four       sedan
# 4           2       audi        gas         std          four       sedan
# 5           2       audi        gas         std           two       sedan
# 6           1       audi        gas         std          four       sedan
# 7           1       audi        gas         std          four       wagon
#
#    drive-wheels  engine-location   wheel-base   length  ...  \
# 3           fwd            front         99.8    176.6  ...
# 4           4wd            front         99.4    176.6  ...
# 5           fwd            front         99.8    177.3  ...
# 6           fwd            front        105.8    192.7  ...
# 7           fwd            front        105.8    192.7  ...
#
#     num-of-cylinders   engine-size   fuel-system  bore  stroke  \
# 3               four           109          mpfi  3.19     3.4
# ...

# %% [markdown]
# Q 5 :- Sort any column of your choice as descending

# %%
sortColumn = df.sort_values(' price', ascending = False)
sortColumn.head()
# Out:
#       symboling   normalized-losses           make  fuel-type  aspiration  \
# 74            1                 NaN  mercedes-benz        gas         std
# 16            0                 NaN            bmw        gas         std
# 73            0                 NaN  mercedes-benz        gas         std
# 128           3                 NaN        porsche        gas         std
# 17            0                 NaN            bmw        gas         std
#
#      num-of-doors   body-style  drive-wheels  engine-location   wheel-base  \
# 74            two      hardtop           rwd            front        112.0
# 16            two        sedan           rwd            front        103.5
# 73           four        sedan           rwd            front        120.9
# 128           two  convertible           rwd             rear         89.5
# 17           four        sedan           rwd            front        110.0
#
# ...

# %% [markdown]
# Q 6 :- Identify duplicates and remove if any

# %%
duplicate = df.isnull()
print(duplicate)
# Out:
#       symboling   normalized-losses        make   fuel-type   aspiration  \
# 0         False                True       False       False        False
# 1         False                True       False       False        False
# 2         False                True       False       False        False
# 3         False               False       False       False        False
# 4         False               False       False       False        False
# ..          ...                 ...         ...         ...          ...
# 200       False               False       False       False        False
# 201       False               False       False       False        False
# 202       False               False       False       False        False
# 203       False               False       False       False        False
# 204       False               False       False       False        False
#
#       num-of-doors   body-style   drive-wheels   engine-location   wheel-base  \
# ...

# %%
# Replace Zeroes
zero_not_accepted = [' normalized-losses']

# Here we are replacing numpy with NaN which means it does not exist
for column in zero_not_accepted :
  df[column] = df[column].replace(0, np.NaN)
  mean = int(df[column].mean(skipna = True))
  df[column] = df[column].replace(np.NaN, mean)

# %% [markdown]
# Q 7 :- Find mean and median of length

# %%
print("Mean : ",df[' length'].mean())
print("Median : ",df[' length'].median())
# Out:
# Mean :  174.04926829268288
# Median :  173.2

# %% [markdown]
# Q 8 :- Plot box plot of any 1 variable of your choice and interpret

# %%
# plot
plt.boxplot(df[' price'], boxprops=dict(color='red'))
plt.title('Boxplot for price feature');

# %% [markdown]
# Q 9 :- Plot scatter plot and interpret

# %%
# plot
# X = dataset.iloc[:, 0:8]
# Y = dataset.iloc[:,8]

x = [' symboling', ' normalized-losses', '      make', ' fuel-type',
       ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels',
       ' engine-location', ' wheel-base', ' length', ' width', ' height']
y = [' curb-weight', ' engine-type', ' num-of-cylinders', ' engine-size',
       ' fuel-system', ' bore', ' stroke', ' compression-ratio', ' horsepower',
       ' peak-rpm', ' city-mpg', ' highway-mpg', ' price']
plt.scatter(x,y)
plt.title('Scatter plot between cars and their price');

plt.show()

# %% [markdown]
# Q 10 :- Plot bar graph

# %%
# Index([' symboling', ' normalized-losses', '      make', ' fuel-type',
#        ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels',
#        ' engine-location', ' wheel-base', ' length', ' width', ' height',
#        ' curb-weight', ' engine-type', ' num-of-cylinders', ' engine-size',
#        ' fuel-system', ' bore', ' stroke', ' compression-ratio', ' horsepower',
#        ' peak-rpm', ' city-mpg', ' highway-mpg', ' price'],
x = [' symboling', ' normalized-losses', '      make', ' fuel-type',
       ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels',
       ' engine-location', ' wheel-base', ' length', ' width', ' height']
y = [' curb-weight', ' engine-type', ' num-of-cylinders', ' engine-size',
       ' fuel-system', ' bore', ' stroke', ' compression-ratio', ' horsepower',
       ' peak-rpm', ' city-mpg', ' highway-mpg', ' price']
plt.bar(x, y, color ='maroon',
        width = 0.5)
# Out:
# <BarContainer object of 13 artists>
