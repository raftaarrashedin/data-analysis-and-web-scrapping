# %%
scientists = [
    {'name': 'Raftaar','field':'math', 'born':2000, 'nobel':False},
     {'name': 'Rashedin','field':'data science', 'born':2000, 'nobel':True},
    	{'name': 'ABC','field':'statistics', 'born':2001, 'nobel':False},
      	{'name': 'XYZ','field':'physics', 'born':1988, 'nobel':True},
        	{'name': 'DEF','field':'chemistry', 'born':1947, 'nobel':True},
            {'name': 'MNO','field':'social science', 'born':1950, 'nobel':False},
            	{'name': 'KYZ','field':'bioloy', 'born':1999, 'nobel':True}
 ]

# %%
scientists
# Out:
# [{'name': 'Raftaar', 'field': 'math', 'born': 2000, 'nobel': False},
#  {'name': 'Rashedin', 'field': 'data science', 'born': 2000, 'nobel': True},
#  {'name': 'ABC', 'field': 'statistics', 'born': 2001, 'nobel': False},
#  {'name': 'XYZ', 'field': 'physics', 'born': 1988, 'nobel': True},
#  {'name': 'DEF', 'field': 'chemistry', 'born': 1947, 'nobel': True},
#  {'name': 'MNO', 'field': 'social science', 'born': 1950, 'nobel': False},
#  {'name': 'KYZ', 'field': 'bioloy', 'born': 1999, 'nobel': True}]

# %%
scientists[3]['name'] = 'Loki'

# %%
scientists
# Out:
# [{'name': 'Raftaar', 'field': 'math', 'born': 2000, 'nobel': False},
#  {'name': 'Rashedin', 'field': 'data science', 'born': 2000, 'nobel': True},
#  {'name': 'ABC', 'field': 'statistics', 'born': 2001, 'nobel': False},
#  {'name': 'Loki', 'field': 'physics', 'born': 1988, 'nobel': True},
#  {'name': 'DEF', 'field': 'chemistry', 'born': 1947, 'nobel': True},
#  {'name': 'MNO', 'field': 'social science', 'born': 1950, 'nobel': False},
#  {'name': 'KYZ', 'field': 'bioloy', 'born': 1999, 'nobel': True}]

# %% [markdown]
# So, we can see this is mutable.

# %%
{'nime': 'xyz', 'field': 'math'}
# Out:
# {'nime': 'xyz', 'field': 'math'}

# %% [markdown]
# Now see what's happening when we use tuple object

# %%
import collections
Scientist = collections.namedtuple('Scientist',[
    'name',
    'field',
    'born',
    'nobel'
])

# %%
Scientist
# Out:
# __main__.Scientist

# %%
xd = Scientist(name='Raftaar',field='Data Science',born = 2000, nobel = False)

# %%
xd.name
# Out:
# 'Raftaar'

# %%
xd.field
# Out:
# 'Data Science'

# %%
xd.born
# Out:
# 2000

# %%
xd.nobel
# Out:
# False

# %%
# If we want to change
xd.name='hehe'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-d3b9d6ee5700> in <cell line: 2>()
#       1 # If we want to change
# ----> 2 xd.name='hehe'
#
# AttributeError: can't set attribute

# %%
 scientists = [
    {'name': 'Raftaar','field':'math', 'born':2000, 'nobel':False},
     {'name': 'Rashedin','field':'data science', 'born':2000, 'nobel':True},
    	{'name': 'ABC','field':'statistics', 'born':2001, 'nobel':False},
      	{'name': 'XYZ','field':'physics', 'born':1988, 'nobel':True},
        	{'name': 'DEF','field':'chemistry', 'born':1947, 'nobel':True},
            {'name': 'MNO','field':'social science', 'born':1950, 'nobel':False},
            	{'name': 'KYZ','field':'bioloy', 'born':1999, 'nobel':True}
 ]

# %%
scientists
# Out:
# [{'name': 'Raftaar', 'field': 'math', 'born': 2000, 'nobel': False},
#  {'name': 'Rashedin', 'field': 'data science', 'born': 2000, 'nobel': True},
#  {'name': 'ABC', 'field': 'statistics', 'born': 2001, 'nobel': False},
#  {'name': 'XYZ', 'field': 'physics', 'born': 1988, 'nobel': True},
#  {'name': 'DEF', 'field': 'chemistry', 'born': 1947, 'nobel': True},
#  {'name': 'MNO', 'field': 'social science', 'born': 1950, 'nobel': False},
#  {'name': 'KYZ', 'field': 'bioloy', 'born': 1999, 'nobel': True}]

# %%
from pprint import pprint
pprint(scientists)
# Out:
# [{'born': 2000, 'field': 'math', 'name': 'Raftaar', 'nobel': False},
#  {'born': 2000, 'field': 'data science', 'name': 'Rashedin', 'nobel': True},
#  {'born': 2001, 'field': 'statistics', 'name': 'ABC', 'nobel': False},
#  {'born': 1988, 'field': 'physics', 'name': 'XYZ', 'nobel': True},
#  {'born': 1947, 'field': 'chemistry', 'name': 'DEF', 'nobel': True},
#  {'born': 1950, 'field': 'social science', 'name': 'MNO', 'nobel': False},
#  {'born': 1999, 'field': 'bioloy', 'name': 'KYZ', 'nobel': True}]

# %%
scientists[3].name = 'Loki'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-cce490e08eb8> in <cell line: 1>()
# ----> 1 scientists[3].name = 'Loki'
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
del scientists[3]

# %%
pprint(scientists)
# Out:
# [{'born': 2000, 'field': 'math', 'name': 'Raftaar', 'nobel': False},
#  {'born': 2000, 'field': 'data science', 'name': 'Rashedin', 'nobel': True},
#  {'born': 2001, 'field': 'statistics', 'name': 'ABC', 'nobel': False},
#  {'born': 1947, 'field': 'chemistry', 'name': 'DEF', 'nobel': True},
#  {'born': 1950, 'field': 'social science', 'name': 'MNO', 'nobel': False},
#  {'born': 1999, 'field': 'bioloy', 'name': 'KYZ', 'nobel': True}]

# %% [markdown]
# # **MAP()**

# %%
# square the item of the list
map(lambda x : x**2,[1,2,3,4,5])

# %%
list(map(lambda x : x**2,[1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
# odd/ even labeling of the item list
l = [1,2,3,4,5]
list(map(lambda x : 'even' if x % 2 == 0 else 'odd',l))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']

# %%
 scientists = [
    {'name': 'Raftaar','field':'math', 'born':2000, 'nobel':False},
     {'name': 'Rashedin','field':'data science', 'born':2000, 'nobel':True},
    	{'name': 'ABC','field':'statistics', 'born':2001, 'nobel':False},
      	{'name': 'XYZ','field':'physics', 'born':1988, 'nobel':True},
        	{'name': 'DEF','field':'chemistry', 'born':1947, 'nobel':True},
            {'name': 'MNO','field':'social science', 'born':1950, 'nobel':False},
            	{'name': 'KYZ','field':'bioloy', 'born':1999, 'nobel':True}
 ]


 list(map(lambda users:users['field'],scientists))
# Out:
# ['math',
#  'data science',
#  'statistics',
#  'physics',
#  'chemistry',
#  'social science',
#  'bioloy']

# %% [markdown]
# # **Filter**

# %%
# fetch fruits starting with 'a'
fruits = ['apple','amrud','cherry']

list(filter(lambda x:x.startswith('a'),fruits))
# Out:
# ['apple', 'amrud']

# %% [markdown]
# # **Reduce**

# %%
import functools

l = [1,2,3,4,5,6,7]
functools.reduce(lambda x,y : x+y,l)
# Out:
# 28

# %%
# max numbers
functools.reduce(lambda x,y : x if x > y else y, l)
# Out:
# 7
